# %%
import numpy as np 
import qutip as qt
from qutip import *
from qutip import Qobj, Bloch
import matplotlib.pyplot as plt

# %% [markdown]
# # Visualiation Test

# %%
x = np.random.uniform(low=0, high=1, size=(100))
plt.plot(x)

# %%
b = Bloch(view=[0,0], figsize=(5,5))
for i in range(0, 100):
    alpha = np.cos(np.pi/2 * x[i])
    beta = np.sin(np.pi/2 * x[i])
    psi = Qobj([[alpha], [beta]])
    b.add_states(psi, kind='point', alpha=0.3)

# %%
b.show()

# %% [markdown]
# # Plot Site 2

# %%
def plot_vec(vec):
    x1 = vec[0]
    x2 = vec[1]
    psi = Qobj([[x1], [x2]])
    return psi

# %%
v1 = [-0.9367914637324803,
  0.3498882013986141]
v2 = [0.3498882013986141,
 0.9367914637324803]

# %%
np.cos(np.pi/2 * 0.95), np.sin(np.pi/2 * 0.95)
# Out:
# (0.078459095727845, 0.996917333733128)

# %%
v1 = [-0.9528571091299792, 0.3034193955245099]
#v2 = [0.078459095727845, 0.996917333733128]

# %%
Ry = ry(2*np.pi)
# Out:
# /var/folders/z3/q9sgsjh15j1_0jw8qp3s0xn40000gn/T/ipykernel_74579/2854868958.py:1: DeprecationWarning: Importing functions/classes of the qip submodule directly from the namespace qutip is deprecated. Please import them from the submodule instead, e.g.
# from qutip.qip.operations import cnot
# from qutip.qip.circuit import QubitCircuit
#
#   Ry = ry(2*np.pi)

# %%
Ry * Qobj([[v1[0]], [v1[1]]])
# Out:
# Quantum object: dims = [[2], [1]], shape = (2, 1), type = ket
# Qobj data =
# [[-0.0784591 ]
#  [-0.99691733]]

# %%
v1 = [1, 0]

# %%
b = Bloch(view=[0,0], figsize=(5,5))
b.add_states(plot_vec(v1))
Ry = ry(np.pi)
#b.add_states(Ry * Qobj([[v1[0]], [v1[1]]]))
b.show()
# Out:
# /var/folders/z3/q9sgsjh15j1_0jw8qp3s0xn40000gn/T/ipykernel_74579/3976724115.py:3: DeprecationWarning: Importing functions/classes of the qip submodule directly from the namespace qutip is deprecated. Please import them from the submodule instead, e.g.
# from qutip.qip.operations import cnot
# from qutip.qip.circuit import QubitCircuit
#
#   Ry = ry(np.pi)

# %%
theta = np.arccos(v1[0])

# %%
theta
# Out:
# 2.7841408946413004

# %%
theta * 180/np.pi
# Out:
# 159.5195228327237

# %%
v1_transformed = [-v1[0], v1[1]]

# %% [markdown]
# Transform the vector outside of the domain

# %%
b = Bloch(view=[0,0], figsize=(5,5))
b.add_states(plot_vec(v1_transformed))
b.add_states(plot_vec(v2))
b.show()

# %%
[np.cos(np.pi/2 * 0.7724391425858189), np.sin(np.pi/2 * 0.7724391425858189)]
# Out:
# [0.3498882013986141, 0.9367914637324802]

# %% [markdown]
# # Site 3

# %%
v1 = [-0.9509215626885478, 0.3094320306852057]
v2 = [0.3094320306852057, 0.9509215626885478]
v1_flipped = [-v1[0], v1[1]]
b = Bloch(view=[0,0], figsize=(5,5))
b.add_states(plot_vec(v1_flipped))
#|b.add_states(plot_vec(v1))
b.add_states(plot_vec(v2))
b.show()

# %% [markdown]
# # Site 4

# %%
v1 = [0.9656306592771889, 0.25991812146116616]
v2 = [0.25991812146116616, 0.9656306592771889]
b = Bloch(view=[0,0], figsize=(5,5))
b.add_states(plot_vec(v1))
#|b.add_states(plot_vec(v1))
b.add_states(plot_vec(v2))
b.show()

# %%
np.arccos()

# %%
np.pi - (np.pi/2 + a)

# %%
print(np.cos(1.3078589176660669 - np.pi/2))
print(np.sin(1.3078589176660669-np.pi/2))
# Out:
# 0.9656306592771889
# -0.2599181214611662

# %% [markdown]
# # Site 5

# %%
v1 = [-0.9528571091299792, 0.3034193955245099]
v2 = [0.3034193955245099, 0.9528571091299792]
b = Bloch(view=[0,0], figsize=(5,5))
b.add_states(plot_vec(v1))
#|b.add_states(plot_vec(v1))
b.add_states(plot_vec(v2))
b.show()

# %%
v1 = [-0.9528571091299792, 0.3034193955245099]

# %%
np.arctan2([v1[0], v1[1]])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[214], line 1
# ----> 1 np.arctan2([v1[0], v1[1]])
#
# TypeError: arctan2() takes from 2 to 3 positional arguments but 1 were given

# %%
v_outcome = [0.9162240348534985, -0.4006663424306753]
v_not_outcome = [0.40083096079756647, -0.916152029341255]
b = Bloch(view=[0,0], figsize=(5,5))
b.add_states(plot_vec(v_outcome))
b.add_states(plot_vec(v_not_outcome))
#|b.add_states(plot_vec(v1))
b.show()

# %%
v_outcome = [0.9162240348534985, -0.4006663424306753]
v_not_outcome = [0.40083096079756647, -0.916152029341255]
b = Bloch(view=[0,0], figsize=(5,5))
b.add_states(plot_vec(np.abs(v_outcome)))
b.add_states(plot_vec(np.abs(v_not_outcome)))
#|b.add_states(plot_vec(v1))
b.show()
