# %%
using Plots
using JLD2
include("/Users/joshua/Desktop/QTNML_paper/QuantumInspiredML/Interpolation/ForecastingMainNew.jl");
include("/Users/joshua/Desktop/QTNML_paper/QuantumInspiredML/LogLoss/RealRealHighDimension.jl");

# %%
f1 = jldopen("all_variable_results.jld2");
tvals = read(f1, "t_vals")
best_idx = read(f1, "best_idx")
mean_score = read(f1, "mean_score")
std_score = read(f1, "std_score");

# %%
plot(tvals, mean_score, xlabel="Conditioning Points", ylabel="MAE", label="", lw=2,
    left_margin=5mm, title="All Variable")
#savefig("all_variable.svg")

# %%
f2 = jldopen("variable_freq_results.jld2");
best_idx_freq = read(f2, "best_idx")
mean_score_freq = read(f2, "mean_score")
std_score_freq = read(f2, "std_score");

# %%
f3 = jldopen("variable_noise_results.jld2");
best_idx_noise = read(f3, "best_idx")
mean_score_noise = read(f3, "mean_score")
std_score_noise = read(f3, "std_score");

# %%
f4 = jldopen("variable_trend_results.jld2");
best_idx_trend = read(f4, "best_idx")
mean_score_trend = read(f4, "mean_score")
std_score_trend = read(f4, "std_score");

# %%
plot(tvals, mean_score, xlabel="Conditioning Points", ylabel="MAE", lw=2,
    left_margin=5mm, label="All Variable")
plot!(tvals, mean_score_freq, label ="Variable Frequency", lw=2)
plot!(tvals, mean_score_noise, label ="Variable Noise", lw=2)
plot!(tvals, mean_score_trend, label = "Variable Trend", lw=2)
#savefig("difficult_synthetic.svg")
