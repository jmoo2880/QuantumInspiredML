# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
data = np.load("KeplarExemplar.npz")
xs = data["xs"]
ground_truth = data["ground_truth"]
mps_fit = data["mps_fit"]
plt.plot(xs, mps_fit, xs, ground_truth)
plt.show()

# %%
plt.plot(xs, mps_fit)

# %%
ground_truth
# Out:
# array([-0.57185003, -0.36282613, -0.17091658, -0.01518426,  0.11732404,
#         0.23868626,  0.35330924,  0.47003746,  0.57436613,  0.6817864 ,
#         0.75139435,  0.79025968,  0.7982439 ,  0.79628238,  0.80599336,
#         0.81564909,  0.8071205 ,  0.90770802,  0.97529208,  0.74088681,
#        -0.34650768, -1.        , -0.8283646 ,  0.31097895,  0.31097895,
#         0.31097895,  0.31097895,  0.31097895,  0.31097895,  0.31097895,
#         0.31097895,  0.31097895,  0.31097895,  0.31097895,  0.31097895,
#         0.31097895,  0.31097895,  0.31097895,  0.31097895,  0.31097895,
#         0.31097895,  0.31097895,  0.31097895,  0.31097895,  0.31097895,
#         0.31097895,  0.31097895,  0.31097895,  0.31097895,  0.31097895,
#         0.31097895,  0.31097895,  0.31097895,  0.31097895,  0.31097895,
#         0.31097895,  0.31097895,  0.31097895,  0.31097895,  0.31097895,
#         0.31097895,  0.31097895,  0.31097895,  0.31097895,  0.31097895,
# ...
